# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
m = 30
n = 6

data =np.zeros((m,n))

for i in range(n):
    data[:,i] = 30 * np.random.randn(m) * (2 * i / (n - 1) - 1) **2 + (i+1)**2

plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data.T)
plt.show()

# %%
# seaborn
sns.boxplot(data=data, orient='v')
plt.show()

# pandas
df = pd.DataFrame(data, columns=['Zero', 'One', 'Two', 'Three', 'Four', 'Five'])
sns.boxplot(data=df,orient='v')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 4
#       1 data1 = np.random.randn()
#       2 data2 = np.random.rand()
# ----> 4 data =np.zeros(data1,data2)
#       6 for i in range(data2):
#       7     data[:,i] = 30 * np.random.randn(data1) * (2 * i / (data2 - 1) - 1) **2 + (i+1)**2
#
# TypeError: expected a sequence of integers or a single integer, got '0.6535930374652078'
