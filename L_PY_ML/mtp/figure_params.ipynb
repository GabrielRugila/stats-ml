# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.arange(0, 100, 2.5)
b = a ** 3.08

fig = plt.figure(figsize=(5, 1.75), dpi=125)
axes1 = fig.add_axes([0, 0, 0.5, 0.5])
axes1.plot(a, b)
fig.savefig('new_fig.png', bbox_inches='tight')
