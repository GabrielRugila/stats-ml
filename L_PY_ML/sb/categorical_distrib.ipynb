# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(df, y='math score', x='test preparation course')
# Out:
# <AxesSubplot: xlabel='test preparation course', ylabel='math score'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df, y='math score', x='parental level of education')
# Out:
# <AxesSubplot: xlabel='parental level of education', ylabel='math score'>

# %%
df.groupby('test preparation course').mean()[['math score', 'reading score', 'writing score']].transpose()
# Out:
# C:\Users\g4bri\AppData\Local\Temp\ipykernel_31480\2662615106.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('test preparation course').mean()[['math score', 'reading score', 'writing score']].transpose()
# test preparation course  completed       none
# math score               69.695531  64.077882
# reading score            73.893855  66.534268
# writing score            74.418994  64.504673

# %%
avg_score = df.groupby(['parental level of education','test preparation course']).mean()[['math score', 'reading score', 'writing score']].transpose()
avg_score
# Out:
# C:\Users\g4bri\AppData\Local\Temp\ipykernel_31480\127998555.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_score = df.groupby(['parental level of education','test preparation course']).mean()[['math score', 'reading score', 'writing score']].transpose()
# parental level of education associate's degree            bachelor's degree  \
# test preparation course              completed       none         completed
# math score                           71.829268  65.571429         73.282609
# reading score                        76.170732  67.857143         76.739130
# writing score                        76.817073  65.842857         78.695652
#
# parental level of education            high school            master's degree  \
# ...

# %% [markdown]
# above and below represent the same data observation, just through different methods

# %%
plt.figure(figsize=(10.5, 6))
sns.boxplot(df, y='math score', x='parental level of education', hue='test preparation course')
plt.legend(bbox_to_anchor=(1.05, 1))

# %%
plt.figure(figsize=(10.5, 6))
sns.boxplot(df, y='writing score', x='parental level of education', hue='test preparation course')
plt.legend(bbox_to_anchor=(1.05, 1))

# %%
plt.figure(figsize=(10.5, 6))
sns.boxplot(df, y='reading score', x='parental level of education', hue='test preparation course')
plt.legend(bbox_to_anchor=(1.05, 1))
